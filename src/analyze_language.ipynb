# %%
import pandas as pd
from nltk.stem.cistem import Cistem
import re
from nltk.probability import FreqDist
from tabulate import tabulate
from tqdm import tqdm

# load fancy nlp pipeline :)))
import spacy

# WE NEED SPEED :(
# spacy.require_gpu()

nlp = spacy.load("de_core_news_lg")

import pickle
from pathlib import Path

out_path = Path("../data/frequencies_per_year_raw_data.pkl")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 14
#       9 import spacy
#      11 # WE NEED SPEED :(
#      12 # spacy.require_gpu()
# ---> 14 nlp = spacy.load("de_core_news_lg")
#      16 import pickle
#      17 from pathlib import Path
#
# File ~/Desktop/tagesschau-language-change/venv/lib/python3.13/site-packages/spacy/__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)     35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)     50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File ~/Desktop/tagesschau-language-change/venv/lib/python3.13/site-packages/spacy/util.py:484, in load_model(name, vocab, disable, enable, exclude, config)
#     482 if name in OLD_MODEL_SHORTCUTS:
#     483     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 484 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'de_core_news_lg'. It doesn't seem to be a Python package or a valid path to a data directory.

# %% [markdown]
# # Load data

# %%
data = pd.read_csv('../data/tagesschau_articles_unique.csv', sep='\t', engine='python', on_bad_lines='warn')
data.head()
# Out:
#          date                                           headline  \
# 0  2025-10-23  ++ Kiew: Übergabe von 1.000 Leichen durch Russ...
# 1  2025-10-23         Zehntausende bei Demonstrationen in Ungarn
# 2  2025-10-23  Litauen meldet Eindringen von russischen Flugz...
# 3  2025-10-23                "Gemeinsam russische U-Boote jagen"
# 4  2025-10-23                        Wetterlage und Temperaturen
#
#                      short_headline  \
# 0           Krieg gegen die Ukraine
# 1                 Wahlkampf-Auftakt
# 2                         Top-Thema
# 3  Deutsch-britische Zusammenarbeit
# 4           Wettervorhersage Europa
#
#                                           short_text  \
# 0  \n                            Ukrainische Behö...
# 1  \n                            Im Frühjahr wähl...
# 2  \n                            Zwei russische M...
# 3  \n                            Großbritannien u...
# 4  \n                            Sturmtief JOSHUA...
#
#                                              article  \
# 0  Ukrainische Behörden haben die Übergabe von 1....
# 1  Im Frühjahr wählt Ungarn ein neues Parlament. ...
# 2  Zwei russische Militärflugzeuge sind nach Anga...
# 3  Großbritannien und Deutschland wollen gemeinsa...
# 4  Sturmtief JOSHUA zieht bis Freitagabend mit se...
#
#                                                 link
# 0   /newsticker/liveblog-ukraine-donnerstag-512.html
# 1           /ausland/europa/ungarn-proteste-132.html
# 2                   /eilmeldung/eilmeldung-8954.html
# 3  /ausland/europa/deutschland-grossbritannien-se...
# 4                                /wetter/europa-welt

# %%
# convert date column to pandas date format
data['date'] = pd.to_datetime(data['date'])

# Some of the articles are missing nan, because its only a video link
drop_indices = data[data['article'].isnull()].index
data = data.drop(index=drop_indices).reset_index(drop=True)

per_year = data.groupby(data['date'].dt.year)

counts_per_year = per_year.size()
print(counts_per_year)
# Out:
# date
# 2018     1409
# 2019     1382
# 2020     1630
# 2021     1119
# 2022      961
# 2023      966
# 2024     3705
# 2025    10889
# dtype: int64

# %%
per_year.get_group(2023).head()
# Out:
#             date                                           headline  \
# 14594 2023-12-31  ++ ZDF-Mitarbeiterin bei Angriff auf Charkiw v...
# 14595 2023-12-31   ++ Israel lässt einige Reservisten nach Hause ++
# 14596 2023-12-31              Drei weitere Verdächtige in Gewahrsam
# 14597 2023-12-31                      Welkom Belgien, adiós Spanien
# 14598 2023-12-31         Königin Margrethe II. kündigt Abdankung an
#
#                            short_headline  \
# 14594             Krieg gegen die Ukraine
# 14595                     Krieg in Nahost
# 14596              Terror-Warnung in Köln
# 14597  Wechsel der EU-Ratspräsidentschaft
# 14598                            Dänemark
#
#                                               short_text  \
# 14594  \n                            Bei den russisch...
# 14595  \n                            Einige Reservist...
# 14596  \n                            In Zusammenhang ...
# 14597  \n                            Turnusgemäß wech...
# 14598  \n                            Seit dem Tod von...
#
#                                                  article  \
# 14594  Bei den russischen Angriffen auf Charkiw ist e...
# 14595  Einige Reservisten der israelischen Streitkräf...
# 14596  In Zusammenhang mit möglichen Anschlagsplänen ...
# 14597  Turnusgemäß wechselt der EU-Ratsvorsitz alle s...
# 14598  Seit dem Tod von Queen Elizabeth II. galt sie ...
#
#                                                     link
# 14594      /newsticker/liveblog-ukraine-sonntag-374.html
# 14595       /newsticker/liveblog-israel-sonntag-126.html
# 14596  /inland/inland-koeln-dom-anschlagsgefahr-100.html
# 14597  /ausland/europa/eu-ratspraesidentschaft-spanie...
# 14598  /ausland/europa/daenemark-koenigin-margrethe-a...

# %%
cistem = Cistem()

def remove_temporary(msg: str) -> str:
    text = re.sub(r'[^a-zA-Z ]', ' ', msg)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

def stem(msg: str) -> str:
    words = msg.split(' ')
    singles = [cistem.stem(word) for word in words]
    return ' '.join(singles)

def get_words_of_interest(text, types=["VERB", "ADJ", "AUX"]):
    doc = nlp(text)
    
    result = {}
    
    for type in types:
        result[type] = [remove_temporary(stem(token.lemma_)) for token in doc if token.pos_ == type]
    
    return result

get_words_of_interest(data['article'][0])
# Out:
# {'VERB': ['meld',
#   'tot',
#   'meld',
#   'beschliess',
#   'meld',
#   'nenn',
#   'meld',
#   'meld',
#   'eindring',
#   'feststell',
#   'teil',
#   'teil',
#   'aufstieg',
#   'patrouillier',
#   'geh',
#   'geh',
#   'geb',
#   'seh',
#   'entscheid',
#   'absag',
#   'verschieb',
#   'sag',
#   'sprech',
#   'brem',
#   'vorberei',
#   'beto',
#   'vorschlag',
#   'zustimm',
#   'auss',
#   'vorwerf',
#   'helf',
#   'sag',
#   'helf',
#   'unterstreich',
#   'geb',
#   'zusich',
#   'liefer',
#   'geb',
#   'lass',
#   'beeintrachtig',
#   'mach',
#   'erklar',
#   'stark',
#   'war',
#   'find',
#   'brauch',
#   'hoff',
#   'hoff',
#   'sag',
#   'setz',
#   'ubergeb',
#   'ubergeb',
#   'erfolg',
#   'teil',
#   'erklar',
#   'beginn',
#   'bedank',
#   'erhal',
#   'bestatig',
#   'ubergeb',
#   'erhal',
#   'berg',
#   'reagier',
#   'komm',
#   'sag',
#   'geb',
#   'geb',
#   'zeig',
#   'umsetz',
#   'geh',
#   'erhoh',
#   'einstell',
#   'komm',
#   'sag',
#   'komm',
#   'vermiss',
#   'tot',
#   'erklar',
#   'aufklar',
#   'fug',
#   'einlief',
#   'mach',
#   'nenn',
#   'handel',
#   'ford',
#   'bitt',
#   'ermoglich',
#   'ford',
#   'unterstutz',
#   'helf',
#   'erlang',
#   'sag',
#   'geb',
#   'verfug',
#   'tot',
#   'tot',
#   'losch',
#   'erklar',
#   'verletz',
#   'tot',
#   'meld',
#   'tot',
#   'mitteil',
#   'befi',
#   'treff',
#   'verletz',
#   'bring',
#   'kauf',
#   'stell',
#   'kauf',
#   'berich',
#   'zitier',
#   'hor',
#   'beitr',
#   'teil',
#   'beschiess',
#   'auslo',
#   'teil',
#   'treff',
#   'grenz',
#   'lieg',
#   'vertag',
#   'vertag',
#   'komm',
#   'mitteil',
#   'erfolg',
#   'drang',
#   'ford',
#   'beto',
#   'kauf',
#   'teilnehm',
#   'kritisier',
#   'schad',
#   'heiss',
#   'unterschatz',
#   'bezeich',
#   'vergleich',
#   'versteh',
#   'zufug',
#   'schnell',
#   'anzieh',
#   'leg',
#   'schnell',
#   'verletz',
#   'beschadig',
#   'sag',
#   'treff',
#   'lieg',
#   'teil',
#   'einsetz',
#   'abschiess',
#   'kritisier',
#   'kritisier',
#   'sag',
#   'hab',
#   'autorisier',
#   'ableh',
#   'kritisier',
#   'treff',
#   'beto',
#   'reparier',
#   'reparier',
#   'bestatig',
#   'dauer',
#   'repariert',
#   'dauer',
#   'erneu',
#   'beschiess',
#   'kapp',
#   'nenn',
#   'abzeich',
#   'verlor',
#   'sag',
#   'droh',
#   'droh',
#   'zieh',
#   'sag',
#   'bera',
#   'sag',
#   'sprech',
#   'verw',
#   'sag',
#   'befurch',
#   'komm',
#   'sag',
#   'hilft',
#   'leb',
#   'versorg',
#   'unterstutz',
#   'heiss',
#   'seh',
#   'zeig',
#   'erziel',
#   'beschaftig',
#   'weiterkomm',
#   'sag',
#   'geb',
#   'sprech',
#   'betreff',
#   'einfrier',
#   'furch',
#   'abgefang',
#   'abgefang',
#   'zerstor',
#   'teil',
#   'erklar',
#   'einstell',
#   'seh',
#   'zeig',
#   'absag',
#   'verhang',
#   'sag',
#   'begeb',
#   'schreib',
#   'stell',
#   'nenn',
#   'bezeich',
#   'folg',
#   'sag',
#   'bleib',
#   'los',
#   'sag',
#   'einig',
#   'treff',
#   'sicherstell',
#   'sag',
#   'arbei',
#   'greif',
#   'treff',
#   'auslo',
#   'teil',
#   'abgefang',
#   'geb',
#   'schreib',
#   'hor',
#   'beleg',
#   'begruss',
#   'sag',
#   'ruf',
#   'erhoh',
#   'verteidig',
#   'ausub',
#   'beend',
#   'erklar',
#   'begruss',
#   'bezeich',
#   'reduzier',
#   'sag',
#   'spur',
#   'bekomm',
#   'begruss',
#   'verhang',
#   'brauch',
#   'steh',
#   'sag',
#   'beschliess',
#   'verabschied',
#   'teil',
#   'beinhal',
#   'einfuhr',
#   'einschrank',
#   'stimm',
#   'aufheb',
#   'senk',
#   'senk',
#   'erwag',
#   'sag',
#   'treff',
#   'treff',
#   'treff',
#   'sag',
#   'biet',
#   'erreich',
#   'ankundig',
#   'nenn',
#   'beend',
#   'sag',
#   'hoff',
#   'meld',
#   'einnehm',
#   'kontrollier',
#   'teil',
#   'uberqu',
#   'einnehm',
#   'meld',
#   'meld',
#   'zuruckerob',
#   'verteidig',
#   'liefer',
#   'dauer',
#   'schul',
#   'erklar',
#   'benotig',
#   'einsetz',
#   'erford',
#   'stell',
#   'bereitstell',
#   'stopp',
#   'verwerf',
#   'beto',
#   'sich',
#   'komm',
#   'verletz',
#   'teil',
#   'anflog',
#   'bestatig',
#   'handel',
#   'sag',
#   'betreff',
#   'hor',
#   'absag',
#   'absag',
#   'angefuhl',
#   'komm',
#   'hinkomm',
#   'sag',
#   'geb',
#   'verhang',
#   'verhang',
#   'beend',
#   'verhang',
#   'zitier',
#   'rich',
#   'fuhr',
#   'betreff',
#   'verstandig',
#   'kauf'],
#  'ADJ': ['ukrainisch',
#   'ukrainisch',
#   'russisch',
#   'wichtig',
#   '',
#   'russisch',
#   'russisch',
#   'russisch',
#   'baltisch',
#   'russisch',
#   'litauisch',
#   'litauisch',
#   'spanisch',
#   'russisch',
#   'kurz',
#   'ukrainisch',
#   'ukrainisch',
#   'perma',
#   'chinesisch',
#   'neu',
#   'russisch',
#   'unfreundlich',
#   'bilateral',
#   'global',
#   'russisch',
#   'positiv',
#   'eingefror',
#   'russisch',
#   'ukrainisch',
#   'positiv',
#   'sogenann',
#   'bedeu',
#   'weit',
#   'international',
#   'rot',
#   'ukrainisch',
#   'international',
#   'rot',
#   'russisch',
#   'ukrainisch',
#   'ukrainisch',
#   'russisch',
#   'langsam',
#   'stetig',
#   'russisch',
#   'ukrainisch',
#   'eige',
#   'gross',
#   'russisch',
#   'vergang',
#   'klei',
#   'britisch',
#   'angekundig',
#   'zentralrussisch',
#   'russisch',
#   'weit',
#   'spa',
#   'weit',
#   'schwer',
#   'schwer',
#   'russisch',
#   'gross',
#   'ukrainisch',
#   'europaisch',
#   'gross',
#   'gross',
#   'europaisch',
#   'nachtlich',
#   'russisch',
#   'ukrainisch',
#   'ostkukrainisch',
#   'weit',
#   'ukrainisch',
#   'ukrainisch',
#   'ukrainisch',
#   'russisch',
#   'ukrainisch',
#   'ostukrainisch',
#   'russisch',
#   'dritt',
#   'russisch',
#   'skandinavisch',
#   'lang',
#   'russisch',
#   'ukrainisch',
#   'eige',
#   'russisch',
#   'ukrainisch',
#   'ukrainisch',
#   'russisch',
#   'juristisch',
#   'mutmasslich',
#   'italienisch',
#   'stundenlang',
#   'russisch',
#   'ukrainisch',
#   'rasch',
#   'eingefror',
#   'russisch',
#   'vorgeschlag',
#   'europaisch',
#   'eingefror',
#   'heutig',
#   'beschloss',
#   'weit',
#   'beschloss',
#   'jung',
#   'russisch',
#   'fehl',
#   'steig',
#   'eige',
#   'eige',
#   'russisch',
#   'russisch',
#   'russisch',
#   'sam',
#   'kiewer',
#   'zwei',
#   'ukrainisch',
#   'jung',
#   'russisch',
#   'neu',
#   'russisch',
#   'neu',
#   'russisch',
#   'chinesisch',
#   'einseitig',
#   'international',
#   'chinesisch',
#   'beschloss',
#   'chinesisch',
#   'besetz',
#   'ukrainisch',
#   'ukrainisch',
#   'staatlich',
#   'zeh',
#   'zwei',
#   'russisch',
#   'ukrainisch',
#   'neu',
#   'stark',
#   'scharf',
#   'deutlich',
#   'stark',
#   'europaisch',
#   'europaisch',
#   'direk',
#   'eingefror',
#   'russisch',
#   'schmerzhaf',
#   'entsprech',
#   'eingefror',
#   'russisch',
#   'schwer',
#   'rechtlich',
#   'vier',
#   'bevorsteh',
#   'vier',
#   'moglich',
#   'psychisch',
#   'korperlich',
#   'kal',
#   'zerstor',
#   'eingefror',
#   'russisch',
#   'eingefror',
#   'russisch',
#   'ernstzunehm',
#   'belgisch',
#   'russisch',
#   'belgisch',
#   'hoch',
#   'ukrainisch',
#   'russisch',
#   'moskau',
#   'flieg',
#   'ukrainisch',
#   'moskau',
#   'russisch',
#   'russisch',
#   'russisch',
#   'eng',
#   'wichtig',
#   'national',
#   'redselig',
#   'troff',
#   'verruck',
#   'fruh',
#   'russisch',
#   'eu staats',
#   'komm',
#   'politisch',
#   'europaisch',
#   'technisch',
#   'politisch',
#   'ukrainisch',
#   'russisch',
#   'gross',
#   'herabfall',
#   'ukrainisch',
#   'neu',
#   'beschloss',
#   '',
#   'vereinig',
#   'neu',
#   'gross',
#   'europaisch',
#   'russisch',
#   'gut',
#   'angegriff',
#   '',
#   '',
#   'danisch',
#   'stufenwei',
#   'russisch',
#   'sogenann',
#   'russisch',
#   'neu',
#   'russisch',
#   'europaisch',
#   'gross',
#   'indisch',
#   'russisch',
#   'vollstandig',
#   'vertrau',
#   'gross',
#   'neu',
#   'gross',
#   'russisch',
#   'massiv',
#   'kurz',
#   'heftig',
#   'eige',
#   'weit',
#   'russisch',
#   'ukrainisch',
#   'ukrainisch',
#   'enorm',
#   'ukrainisch',
#   'begonn',
#   'russisch',
#   'vergang',
#   'eige',
#   'russisch',
#   'schwer',
#   'russisch',
#   'weiter',
#   'stell',
#   'baldig',
#   'eige',
#   'weiss',
#   'russisch',
#   'neu',
#   'gross',
#   'russisch',
#   'gross',
#   'finanzier',
#   'russisch',
#   'eng',
#   'weitreich',
#   'neu'],
#  'AUX': ['hab',
#   'sein',
#   'werd',
#   'sein',
#   'hab',
#   'sein',
#   'sein',
#   'sein',
#   'werd',
#   'hab',
#   'hab',
#   'sein',
#   'muss',
#   'hab',
#   'hab',
#   'sein',
#   'hab',
#   'sein',
#   'hab',
#   'hab',
#   'werd',
#   'werd',
#   'sein',
#   'werd',
#   'sein',
#   'werd',
#   'sein',
#   'sein',
#   'hab',
#   'hab',
#   'sein',
#   'werd',
#   'sein',
#   'werd',
#   'konn',
#   'hab',
#   'sein',
#   'hab',
#   'hab',
#   'werd',
#   'sein',
#   'werd',
#   'sein',
#   'werd',
#   'werd',
#   'werd',
#   'werd',
#   'werd',
#   'soll',
#   'hab',
#   'hab',
#   'hab',
#   'sein',
#   'werd',
#   'sein',
#   'werd',
#   'werd',
#   'werd',
#   'werd',
#   'sein',
#   'werd',
#   'werd',
#   'woll',
#   'sein',
#   'hab',
#   'hab',
#   'sein',
#   'hab',
#   'hab',
#   'sein',
#   'sein',
#   'woll',
#   'durf',
#   'sein',
#   'sein',
#   'hab',
#   'werd',
#   'konn',
#   'hab',
#   'sein',
#   'werd',
#   'sein',
#   'werd',
#   'sein',
#   'werd',
#   'sein',
#   'sein',
#   'werd',
#   'sein',
#   'werd',
#   'hab',
#   'werd',
#   'sein',
#   'sein',
#   'sein',
#   'sein',
#   'werd',
#   'hab',
#   'werd',
#   'sein',
#   'sein',
#   'hab',
#   'sein',
#   'hab',
#   'werd',
#   'werd',
#   'sein',
#   'hab',
#   'konn',
#   'sein',
#   'hab',
#   'werd',
#   'sein',
#   'werd',
#   'werd',
#   'muss',
#   'sein',
#   'hab',
#   'sein',
#   'werd',
#   'hab',
#   'hab',
#   'sein',
#   'sein',
#   'sein',
#   'hab',
#   'sein',
#   'hab',
#   'werd',
#   'sein',
#   'muss',
#   'werd',
#   'sein',
#   'werd',
#   'werd',
#   'sein',
#   'hab',
#   'werd',
#   'sein',
#   'hab',
#   'hab',
#   'sein',
#   'muss',
#   'muss',
#   'hab',
#   'sein',
#   'werd',
#   'muss',
#   'sein',
#   'sein',
#   'hab',
#   'werd',
#   'hab',
#   'durf',
#   'durf',
#   'sein',
#   'woll',
#   'woll',
#   'moch',
#   'sein',
#   'hab',
#   'sein',
#   'werd',
#   'hab',
#   'werd',
#   'hab',
#   'hab',
#   'hab',
#   'werd',
#   'werd',
#   'hab',
#   'muss',
#   'sein',
#   'sein',
#   'werd',
#   'sein',
#   'konn',
#   'werd',
#   'sein',
#   'woll',
#   'hab',
#   'hab',
#   'hab',
#   'werd',
#   'muss',
#   'soll',
#   'werd',
#   'sein',
#   'hab',
#   'woll']}

# %%
# Convert all articles
frequencies_per_year_raw_data = {}
frequencies_per_year = {}

for group, entry in per_year:
    articles = entry["article"]

    verbs = []
    adj = []
    aux = []

    articles = tqdm(articles, desc=f"Processing year {group}")
    for article in articles:
        words = get_words_of_interest(article)

        verbs.extend(words["VERB"])
        adj.extend(words["ADJ"])
        aux.extend(words["AUX"])

    freq_verbs = FreqDist(verbs)
    freq_adj = FreqDist(adj)
    freq_aux = FreqDist(aux)

    frequencies_per_year[group] = {"VERB": freq_verbs, "ADJ": freq_adj, "AUX": freq_aux}
    frequencies_per_year_raw_data[group] = {"VERB": verbs, "ADJ": adj, "AUX": aux}
    
# Store raw data to file for later use
with out_path.open("wb") as f:
    pickle.dump(frequencies_per_year_raw_data, f, protocol=pickle.HIGHEST_PROTOCOL)

print("Data saved to", out_path)
# Out:
# Processing year 2018:   0%|          | 0/1409 [00:00<?, ?it/s]
# Processing year 2018: 100%|██████████| 1409/1409 [01:42<00:00, 13.81it/s]
# Processing year 2019: 100%|██████████| 1382/1382 [01:37<00:00, 14.20it/s]
# Processing year 2020: 100%|██████████| 1630/1630 [02:16<00:00, 11.93it/s]
# Processing year 2021: 100%|██████████| 1119/1119 [01:37<00:00, 11.50it/s]
# Processing year 2022: 100%|██████████| 961/961 [01:18<00:00, 12.17it/s]
# Processing year 2023: 100%|██████████| 966/966 [01:21<00:00, 11.83it/s]
# Processing year 2024: 100%|██████████| 3705/3705 [05:52<00:00, 10.50it/s]
# Processing year 2025: 100%|██████████| 10889/10889 [17:04<00:00, 10.63it/s]
# Data saved to ../data/frequencies_per_year_raw_data.pkl

# %%
print("Top frequencies per year:")
for year, freq in frequencies_per_year.items():
    verbs = freq['VERB']
    adj = freq['ADJ']
    aux = freq['AUX']
    
    print(f"Year {year}:")
    
    number = 20
    verbs_head = verbs.most_common(number)
    
    adj_head = adj.most_common(number)
    aux_head = aux.most_common(number)
    
    df_verbs = pd.DataFrame(verbs_head, columns=['Verb', 'Frequency'])
    print(tabulate(df_verbs, headers='keys', tablefmt='github', showindex=False))

    df_adj = pd.DataFrame(adj_head, columns=['Adj', 'Frequency'])
    print(tabulate(df_adj, headers='keys', tablefmt='github', showindex=False))

    df_aux = pd.DataFrame(aux_head, columns=['Aux', 'Frequency'])
    print(tabulate(df_aux, headers='keys', tablefmt='github', showindex=False))
# Out:
# Top frequencies per year:
# Year 2018:
# | Verb   |   Frequency |
# |--------|-------------|
# | sag    |        2758 |
# | geb    |        2298 |
# | geh    |        1488 |
# | komm   |        1361 |
# | mach   |        1172 |
# | hab    |        1139 |
# | seh    |         911 |
# | steh   |         821 |
# | bleib  |         719 |
# | erklar |         699 |
# | lass   |         630 |
# | stell  |         619 |
# | ford   |         589 |
# | sprech |         581 |
# | lte    |         569 |
# | heiss  |         558 |
# | find   |         550 |
# | hal    |         532 |
# | zeig   |         493 |
# | lieg   |         484 |
# | Adj           |   Frequency |
# |---------------|-------------|
# | europaisch    |        1322 |
# | neu           |        1261 |
# | gross         |        1072 |
# | ander         |        1049 |
# | deutsch       |         938 |
# |               |         643 |
# | weit          |         617 |
# | russisch      |         533 |
# | ers           |         502 |
# | vergang       |         488 |
# | politisch     |         474 |
# | hoch          |         429 |
# | britisch      |         418 |
# | gut           |         407 |
# | eige          |         404 |
# | wichtig       |         336 |
# | letz          |         305 |
# | international |         302 |
# | sogenann      |         297 |
# | turkisch      |         274 |
# | Aux    |   Frequency |
# |--------|-------------|
# | sein   |       15253 |
# | werd   |        9596 |
# | hab    |        7955 |
# | konn   |        3783 |
# | soll   |        2885 |
# | muss   |        2455 |
# | woll   |        1886 |
# | durf   |         818 |
# | moch   |         119 |
# | mog    |          47 |
# | konnt  |          12 |
# | war    |           6 |
# | will   |           6 |
# | bin    |           6 |
# | musst  |           4 |
# | wurd   |           4 |
# | bleib  |           3 |
# | wurde  |           3 |
# | wuss   |           2 |
# | sodass |           2 |
# Year 2019:
# | Verb   |   Frequency |
# |--------|-------------|
# | sag    |        2322 |
# | geb    |        2157 |
# | geh    |        1414 |
# | komm   |        1271 |
# | mach   |        1049 |
# | hab    |         936 |
# | seh    |         843 |
# | steh   |         797 |
# | erklar |         662 |
# | bleib  |         658 |
# | lass   |         622 |
# | ford   |         573 |
# | find   |         561 |
# | lte    |         560 |
# | lieg   |         536 |
# | stell  |         523 |
# | bring  |         504 |
# | heiss  |         501 |
# | hal    |         494 |
# | zeig   |         471 |
# | Adj        |   Frequency |
# |------------|-------------|
# | neu        |        1413 |
# |            |        1185 |
# | europaisch |        1126 |
# | britisch   |        1059 |
# | gross      |        1019 |
# | ander      |         994 |
# | deutsch    |         725 |
# | weit       |         694 |
# | ers        |         544 |
# | vergang    |         447 |
# | politisch  |         429 |
# | eige       |         409 |
# | hoch       |         380 |
# | gut        |         375 |
# | zwei       |         332 |
# | wichtig    |         297 |
# | letz       |         291 |
# | nach       |         278 |
# | sogenann   |         259 |
# | lang       |         255 |
# | Aux    |   Frequency |
# |--------|-------------|
# | sein   |       13628 |
# | werd   |        9011 |
# | hab    |        7369 |
# | konn   |        3473 |
# | soll   |        2601 |
# | muss   |        2406 |
# | woll   |        2133 |
# | durf   |         719 |
# | moch   |          97 |
# | mog    |          42 |
# | konnt  |           8 |
# | war    |           7 |
# | will   |           6 |
# | wollt  |           4 |
# | sei    |           4 |
# | bin    |           3 |
# | sodass |           3 |
# | wuss   |           2 |
# | kann   |           2 |
# | musst  |           2 |
# Year 2020:
# | Verb   |   Frequency |
# |--------|-------------|
# | geb    |        3316 |
# | sag    |        3209 |
# | geh    |        1817 |
# | komm   |        1687 |
# | hab    |        1411 |
# | mach   |        1296 |
# | lte    |        1167 |
# | seh    |        1105 |
# | steh   |        1024 |
# | bleib  |        1000 |
# | lass   |         841 |
# | erklar |         814 |
# | lieg   |         791 |
# | zeig   |         743 |
# | heiss  |         727 |
# | hal    |         716 |
# | stell  |         686 |
# | ford   |         678 |
# | sprech |         637 |
# | fuhr   |         586 |
# | Adj           |   Frequency |
# |---------------|-------------|
# | neu           |        1532 |
# |               |        1493 |
# | gross         |        1481 |
# | ander         |        1441 |
# | weit          |        1139 |
# | deutsch       |        1018 |
# | ers           |         972 |
# | europaisch    |         916 |
# | vergang       |         696 |
# | hoch          |         588 |
# | eige          |         569 |
# | russisch      |         481 |
# | politisch     |         480 |
# | offentlich    |         448 |
# | wichtig       |         435 |
# | gut           |         424 |
# | klei          |         411 |
# | sogenann      |         405 |
# | zwei          |         385 |
# | international |         373 |
# | Aux    |   Frequency |
# |--------|-------------|
# | sein   |       20389 |
# | werd   |       14060 |
# | hab    |        9377 |
# | konn   |        5353 |
# | soll   |        4050 |
# | muss   |        3177 |
# | woll   |        1978 |
# | durf   |        1517 |
# | moch   |         131 |
# | mog    |          38 |
# | konnt  |           7 |
# | sodass |           6 |
# | hatt   |           5 |
# | war    |           5 |
# | bekomm |           5 |
# | wurd   |           4 |
# | musst  |           3 |
# | sei    |           3 |
# | kann   |           3 |
# | wuss   |           3 |
# Year 2021:
# | Verb   |   Frequency |
# |--------|-------------|
# | geb    |        2269 |
# | sag    |        2157 |
# | geh    |        1330 |
# | komm   |        1197 |
# | mach   |        1013 |
# | hab    |        1004 |
# | seh    |         844 |
# | steh   |         800 |
# | lass   |         728 |
# | zeig   |         659 |
# | erklar |         658 |
# | lieg   |         647 |
# | lte    |         573 |
# | heiss  |         559 |
# | bleib  |         547 |
# | sprech |         497 |
# | hal    |         459 |
# | fuhr   |         434 |
# | stell  |         431 |
# | find   |         426 |
# | Adj        |   Frequency |
# |------------|-------------|
# | neu        |        1243 |
# | ander      |        1080 |
# | gross      |        1066 |
# | deutsch    |         824 |
# |            |         688 |
# | ers        |         677 |
# | weit       |         653 |
# | vergang    |         602 |
# | hoch       |         517 |
# | eige       |         474 |
# | politisch  |         398 |
# | europaisch |         398 |
# | russisch   |         378 |
# | jung       |         333 |
# | gut        |         327 |
# | klei       |         311 |
# | wichtig    |         308 |
# | sogenann   |         298 |
# | aktuell    |         259 |
# | letz       |         256 |
# | Aux      |   Frequency |
# |----------|-------------|
# | sein     |       14661 |
# | werd     |        9134 |
# | hab      |        6916 |
# | konn     |        3668 |
# | soll     |        2238 |
# | muss     |        2083 |
# | woll     |        1299 |
# | durf     |         661 |
# | moch     |         114 |
# | mog      |          35 |
# | war      |           8 |
# | sodass   |           6 |
# | konnt    |           5 |
# | bin      |           4 |
# | musst    |           4 |
# | wuss     |           3 |
# | wir      |           2 |
# | kann     |           2 |
# | hatt     |           2 |
# | ffp mask |           2 |
# Year 2022:
# | Verb   |   Frequency |
# |--------|-------------|
# | sag    |        2030 |
# | geb    |        1703 |
# | geh    |         986 |
# | komm   |         953 |
# | hab    |         829 |
# | mach   |         713 |
# | seh    |         702 |
# | steh   |         621 |
# | erklar |         544 |
# | bleib  |         497 |
# | lass   |         477 |
# | lieg   |         459 |
# | lte    |         436 |
# | ford   |         429 |
# | heiss  |         421 |
# | sprech |         406 |
# | zeig   |         400 |
# | hal    |         377 |
# | fuhr   |         347 |
# | stell  |         345 |
# | Adj           |   Frequency |
# |---------------|-------------|
# | russisch      |        1141 |
# | neu           |         875 |
# | gross         |         841 |
# | ander         |         787 |
# | deutsch       |         663 |
# |               |         604 |
# | weit          |         559 |
# | ers           |         544 |
# | hoch          |         511 |
# | vergang       |         472 |
# | ukrainisch    |         430 |
# | eige          |         375 |
# | europaisch    |         349 |
# | politisch     |         304 |
# | wichtig       |         284 |
# | gut           |         267 |
# | international |         252 |
# | sogenann      |         238 |
# | klei          |         205 |
# | schwer        |         199 |
# | Aux        |   Frequency |
# |------------|-------------|
# | sein       |       11565 |
# | werd       |        7272 |
# | hab        |        5645 |
# | konn       |        2868 |
# | soll       |        1833 |
# | muss       |        1593 |
# | woll       |        1132 |
# | durf       |         508 |
# | moch       |          81 |
# | mog        |          21 |
# | sodass     |           4 |
# | kann       |           4 |
# | konnt      |           3 |
# | will       |           3 |
# | war        |           3 |
# | musst      |           2 |
# | wurd       |           2 |
# | sei        |           1 |
# | darf       |           1 |
# | wochenlang |           1 |
# Year 2023:
# | Verb   |   Frequency |
# |--------|-------------|
# | sag    |        2327 |
# | geb    |        1652 |
# | komm   |         983 |
# | geh    |         968 |
# | mach   |         757 |
# | hab    |         710 |
# | seh    |         632 |
# | steh   |         591 |
# | erklar |         582 |
# | ford   |         508 |
# | heiss  |         479 |
# | sprech |         451 |
# | lieg   |         446 |
# | zeig   |         444 |
# | lass   |         441 |
# | bleib  |         435 |
# | steig  |         414 |
# | lte    |         393 |
# | teil   |         382 |
# | stell  |         349 |
# | Adj           |   Frequency |
# |---------------|-------------|
# | gross         |         880 |
# | russisch      |         868 |
# | neu           |         816 |
# | deutsch       |         772 |
# | weit          |         699 |
# | ander         |         673 |
# | vergang       |         576 |
# | ers           |         559 |
# |               |         538 |
# | hoch          |         500 |
# | israelisch    |         406 |
# | eige          |         395 |
# | ukrainisch    |         382 |
# | politisch     |         284 |
# | gut           |         282 |
# | international |         261 |
# | jung          |         255 |
# | wichtig       |         254 |
# | europaisch    |         243 |
# | sogenann      |         237 |
# | Aux         |   Frequency |
# |-------------|-------------|
# | sein        |       11756 |
# | werd        |        7412 |
# | hab         |        6403 |
# | konn        |        2594 |
# | soll        |        1716 |
# | muss        |        1466 |
# | woll        |        1051 |
# | durf        |         517 |
# | moch        |          81 |
# | mog         |          25 |
# | konnt       |           7 |
# | sodass      |           7 |
# | will        |           3 |
# | hatt        |           2 |
# | bin         |           2 |
# | kann        |           2 |
# | lass        |           2 |
# | seid        |           2 |
# | infolgedess |           1 |
# | seie        |           1 |
# Year 2024:
# | Verb   |   Frequency |
# |--------|-------------|
# | sag    |       10233 |
# | geb    |        6786 |
# | geh    |        4314 |
# | komm   |        4257 |
# | mach   |        3337 |
# | hab    |        3035 |
# | erklar |        2888 |
# | steh   |        2821 |
# | seh    |        2671 |
# | ford   |        2245 |
# | heiss  |        2225 |
# | teil   |        2172 |
# | lieg   |        2165 |
# | sprech |        1993 |
# | bleib  |        1935 |
# | lass   |        1903 |
# | zeig   |        1860 |
# | stell  |        1737 |
# | berich |        1711 |
# | lte    |        1577 |
# | Adj           |   Frequency |
# |---------------|-------------|
# | russisch      |        4468 |
# | neu           |        4293 |
# | israelisch    |        3756 |
# | gross         |        3673 |
# | weit          |        3317 |
# | ander         |        2872 |
# | deutsch       |        2789 |
# |               |        2624 |
# | ers           |        2427 |
# | ukrainisch    |        2355 |
# | vergang       |        2133 |
# | hoch          |        1814 |
# | eige          |        1800 |
# | politisch     |        1440 |
# | europaisch    |        1423 |
# | wichtig       |        1393 |
# | syrisch       |        1318 |
# | gut           |        1142 |
# | international |        1133 |
# | moglich       |        1080 |
# | Aux    |   Frequency |
# |--------|-------------|
# | sein   |       48652 |
# | werd   |       32279 |
# | hab    |       29604 |
# | konn   |       10504 |
# | soll   |        7628 |
# | muss   |        6076 |
# | woll   |        5042 |
# | durf   |        1875 |
# | moch   |         369 |
# | mog    |          90 |
# | konnt  |          22 |
# | sodass |          20 |
# | will   |          12 |
# | war    |           7 |
# | wuss   |           6 |
# | wurd   |           6 |
# | wir    |           5 |
# | sei    |           5 |
# | kann   |           4 |
# | bin    |           4 |
# Year 2025:
# | Verb   |   Frequency |
# |--------|-------------|
# | sag    |       30529 |
# | geb    |       19988 |
# | geh    |       12492 |
# | komm   |       12024 |
# | mach   |        9524 |
# | hab    |        8761 |
# | seh    |        8589 |
# | erklar |        8255 |
# | steh   |        8130 |
# | heiss  |        6457 |
# | ford   |        6349 |
# | lieg   |        6254 |
# | zeig   |        6252 |
# | bleib  |        6201 |
# | sprech |        6023 |
# | lass   |        5589 |
# | teil   |        5566 |
# | stell  |        4709 |
# | lte    |        4585 |
# | fuhr   |        4546 |
# | Adj           |   Frequency |
# |---------------|-------------|
# | neu           |       14224 |
# | gross         |       11078 |
# | russisch      |       10362 |
# | weit          |        9422 |
# | deutsch       |        9074 |
# | israelisch    |        8670 |
# | ander         |        8583 |
# | ers           |        7900 |
# | vergang       |        6799 |
# | ukrainisch    |        6552 |
# |               |        6265 |
# | europaisch    |        5855 |
# | hoch          |        5796 |
# | eige          |        5006 |
# | wichtig       |        4141 |
# | politisch     |        3888 |
# | gut           |        3860 |
# | jung          |        3536 |
# | international |        3500 |
# | moglich       |        3155 |
# | Aux    |   Frequency |
# |--------|-------------|
# | sein   |      141669 |
# | werd   |       92421 |
# | hab    |       81247 |
# | konn   |       31186 |
# | soll   |       23430 |
# | muss   |       18263 |
# | woll   |       15911 |
# | durf   |        5824 |
# | moch   |        1109 |
# | mog    |         276 |
# | sodass |          55 |
# | konnt  |          54 |
# | war    |          49 |
# | sei    |          21 |
# | wir    |          20 |
# | wuss   |          19 |
# | wurd   |          17 |
# | kann   |          14 |
# | bin    |          13 |
# | will   |          12 |
